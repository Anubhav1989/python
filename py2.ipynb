# %%
#section A
import pandas as pd

df = pd.read_csv('/content/Titanic-Dataset (1).csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#section B
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=df.drop(columns=['Cabin'])

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df[['Age','Embarked']].isna().sum()
# Out:
# Age         0
# Embarked    0
# dtype: int64

# %%
df=df.drop_duplicates()

# %%
#sectioon C
df['Sex']=df['Sex'].map({'male':0,'female':1})

# %%
df['Embarked']=df['Embarked'].astype('category')

# %%
df['FamilySize']=df['SibSp']+df['Parch']+1

# %%
df.rename(columns={'Pclass':'PassengerClass'},inplace=True)

# %%
df['Fare']=df['Fare'].astype(int)

# %%
#section D
df[df['Survived']==1]
# Out:
#      PassengerId  Survived  PassengerClass  \
# 1              2         1               1
# 2              3         1               3
# 3              4         1               1
# 8              9         1               3
# 9             10         1               2
# ..           ...       ...             ...
# 875          876         1               3
# 879          880         1               1
# 880          881         1               2
# 887          888         1               1
# 889          890         1               1
#
#                                                   Name  Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)    1  14.0      1
# ...

# %%
df[df['PassengerClass']==1]
# Out:
#      PassengerId  Survived  PassengerClass  \
# 1              2         1               1
# 3              4         1               1
# 6              7         0               1
# 11            12         1               1
# 23            24         1               1
# ..           ...       ...             ...
# 871          872         1               1
# 872          873         0               1
# 879          880         1               1
# 887          888         1               1
# 889          890         1               1
#
#                                                   Name  Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 6                              McCarthy, Mr. Timothy J    0  54.0      0
# 11                            Bonnell, Miss. Elizabeth    1  58.0      0
# 23                        Sloper, Mr. William Thompson    0  28.0      0
# ...

# %%
df[df['Age']>50]
# Out:
#      PassengerId  Survived  PassengerClass  \
# 6              7         0               1
# 11            12         1               1
# 15            16         1               2
# 33            34         0               2
# 54            55         0               1
# ..           ...       ...             ...
# 820          821         1               1
# 829          830         1               1
# 851          852         0               3
# 857          858         1               1
# 879          880         1               1
#
#                                                   Name  Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    0  54.0      0
# 11                            Bonnell, Miss. Elizabeth    1  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)     1  55.0      0
# 33                               Wheadon, Mr. Edward H    0  66.0      0
# 54                      Ostby, Mr. Engelhart Cornelius    0  65.0      0
# ...

# %%
df[(df['Sex']==1) & (df['Survived']==1)]
# Out:
#      PassengerId  Survived  PassengerClass  \
# 1              2         1               1
# 2              3         1               3
# 3              4         1               1
# 8              9         1               3
# 9             10         1               2
# ..           ...       ...             ...
# 874          875         1               2
# 875          876         1               3
# 879          880         1               1
# 880          881         1               2
# 887          888         1               1
#
#                                                   Name  Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)    1  14.0      1
# ...

# %%
df[df['Fare']>df['Fare'].mean()]
# Out:
#      PassengerId  Survived  PassengerClass  \
# 1              2         1               1
# 3              4         1               1
# 6              7         0               1
# 23            24         1               1
# 27            28         0               1
# ..           ...       ...             ...
# 856          857         1               1
# 863          864         0               3
# 867          868         0               1
# 871          872         1               1
# 879          880         1               1
#
#                                                   Name  Sex        Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 6                              McCarthy, Mr. Timothy J    0  54.000000      0
# 23                        Sloper, Mr. William Thompson    0  28.000000      0
# ...

# %%
df[['Name','Sex','Age','Survived']]
# Out:
#                                                   Name  Sex        Age  \
# 0                              Braund, Mr. Owen Harris    0  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000
# 2                               Heikkinen, Miss. Laina    1  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000
# 4                             Allen, Mr. William Henry    0  35.000000
# ..                                                 ...  ...        ...
# 886                              Montvila, Rev. Juozas    0  27.000000
# 887                       Graham, Miss. Margaret Edith    1  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"    1  29.699118
# 889                              Behr, Mr. Karl Howell    0  26.000000
# 890                                Dooley, Mr. Patrick    0  32.000000
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# ...

# %%
df.loc[100:150]
# Out:
#      PassengerId  Survived  PassengerClass  \
# 100          101         0               3
# 101          102         0               3
# 102          103         0               1
# 103          104         0               3
# 104          105         0               3
# 105          106         0               3
# 106          107         1               3
# 107          108         1               3
# 108          109         0               3
# 109          110         1               3
# 110          111         0               1
# 111          112         0               3
# 112          113         0               3
# 113          114         0               3
# 114          115         0               3
# 115          116         0               3
# 116          117         0               3
# 117          118         0               2
# 118          119         0               1
# 119          120         0               3
# 120          121         0               2
# ...

# %%
df.iloc[:10,:6]
# Out:
#    PassengerId  Survived  PassengerClass  \
# 0            1         0               3
# 1            2         1               1
# 2            3         1               3
# 3            4         1               1
# 4            5         0               3
# 5            6         0               3
# 6            7         0               1
# 7            8         0               3
# 8            9         1               3
# 9           10         1               2
#
#                                                 Name  Sex        Age
# 0                            Braund, Mr. Owen Harris    0  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000
# 2                             Heikkinen, Miss. Laina    1  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000
# 4                           Allen, Mr. William Henry    0  35.000000
# 5                                   Moran, Mr. James    0  29.699118
# ...

# %%
#section E
df.sort_values(by='Fare',ascending=False)
# Out:
#      PassengerId  Survived  PassengerClass  \
# 737          738         1               1
# 679          680         1               1
# 258          259         1               1
# 438          439         0               1
# 341          342         1               1
# ..           ...       ...             ...
# 277          278         0               2
# 597          598         0               3
# 466          467         0               2
# 481          482         0               2
# 413          414         0               2
#
#                                    Name  Sex        Age  SibSp  Parch  \
# 737              Lesurer, Mr. Gustave J    0  35.000000      0      0
# 679  Cardeza, Mr. Thomas Drake Martinez    0  36.000000      0      1
# 258                    Ward, Miss. Anna    1  35.000000      0      0
# 438                   Fortune, Mr. Mark    0  64.000000      1      4
# 341      Fortune, Miss. Alice Elizabeth    1  24.000000      3      2
# ...

# %%
df.sort_values(by=['PassengerClass','Fare'],ascending=False)
# Out:
#      PassengerId  Survived  PassengerClass                             Name  \
# 159          160         0               3       Sage, Master. Thomas Henry
# 180          181         0               3     Sage, Miss. Constance Gladys
# 201          202         0               3              Sage, Mr. Frederick
# 324          325         0               3         Sage, Mr. George John Jr
# 792          793         0               3          Sage, Miss. Stella Anna
# ..           ...       ...             ...                              ...
# 263          264         0               1            Harrison, Mr. William
# 633          634         0               1    Parr, Mr. William Henry Marsh
# 806          807         0               1           Andrews, Mr. Thomas Jr
# 815          816         0               1                 Fry, Mr. Richard
# 822          823         0               1  Reuchlin, Jonkheer. John George
#
# ...

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df.groupby('PassengerClass')['Fare'].mean()
# Out:
# PassengerClass
# 1    83.745370
# 2    20.456522
# 3    13.173116
# Name: Fare, dtype: float64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# Sex
# 0    577
# 1    314
# Name: count, dtype: int64

# %%
#section F
x=df.groupby('PassengerClass').agg({'Age':mean,'Fare':mean,'Survived':mean})
# Out:
# /tmp/ipython-input-3285274314.py:2: FutureWarning: The provided callable <function mean at 0x7f0ae5df7880> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   x=df.groupby('PassengerClass').agg({'Age':mean,'Fare':mean,'Survived':mean})

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# 0    0.188908
# 1    0.742038
# Name: Survived, dtype: float64

# %%
def x(age):
  if age<12:
    return 'Child'
  elif age<60:
    return 'Adult'
  else:
    return 'Senior'

df['AgeGroup']=df['Age'].apply(x)

# %%
df['AgeGroup'].value_counts()
# Out:
# AgeGroup
# Adult     797
# Child      68
# Senior     26
# Name: count, dtype: int64

# %%
x.reset_index()
# Out:
#    PassengerClass        Age       Fare  Survived
# 0               1  37.048118  83.745370  0.629630
# 1               2  29.866958  20.456522  0.472826
# 2               3  26.403259  13.173116  0.242363

# %%
#section G
df[df['Fare']==df['Fare'].max()]
# Out:
#      PassengerId  Survived  PassengerClass  \
# 258          259         1               1
# 679          680         1               1
# 737          738         1               1
#
#                                    Name  Sex   Age  SibSp  Parch    Ticket  \
# 258                    Ward, Miss. Anna    1  35.0      0      0  PC 17755
# 679  Cardeza, Mr. Thomas Drake Martinez    0  36.0      0      1  PC 17755
# 737              Lesurer, Mr. Gustave J    0  35.0      0      0  PC 17755
#
#      Fare Embarked  FamilySize AgeGroup
# 258   512        C           1    Adult
# 679   512        C           2    Adult
# 737   512        C           1    Adult

# %%
df['Embarked'].value_counts().head(1)
# Out:
# Embarked
# S    646
# Name: count, dtype: int64

# %%
df.to_csv('Titanic_Cleaned.csv.')
