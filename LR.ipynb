# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/insurance - insurance.csv')
df.head(2)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
x=df.drop(columns=['charges'])
y=df['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,
                                               random_state=21)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
x['sex']=lb.fit_transform(x['sex'])
x['smoker']=lb.fit_transform(x['smoker'])
x['region']=lb.fit_transform(x['region'])

# %%
x.head()
# Out:
#    age  sex     bmi  children  smoker  region
# 0   19    0  27.900         0       1       3
# 1   18    1  33.770         1       0       2
# 2   28    1  33.000         3       0       2
# 3   33    1  22.705         0       0       1
# 4   32    1  28.880         0       0       1

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7348136813877889

# %%
df=pd.read_csv('/content/credit_scoring - credit_scoring.csv')
df.head(2)
# Out:
#    Age Gender Marital Status Education Level Employment Status  \
# 0   60   Male        Married          Master          Employed
# 1   25   Male        Married     High School        Unemployed
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22             2685                          2
# 1                      0.20             2371                          9
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan
# 0      4675000           2.65         48  Personal Loan
# 1      3619000           5.19         60      Auto Loan

# %%
df.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Marital Status               0
# Education Level              0
# Employment Status            0
# Credit Utilization Ratio     0
# Payment History              0
# Number of Credit Accounts    0
# Loan Amount                  0
# Interest Rate                0
# Loan Term                    0
# Type of Loan                 0
# dtype: int64

# %%
x=df.drop(columns=['Loan Amount'])
y=df['Loan Amount']

# %%
x['Gender']=lb.fit_transform(x['Gender'])
x['Marital Status']=lb.fit_transform(x['Marital Status'])
x['Education Level']=lb.fit_transform(x['Education Level'])
x['Employment Status']=lb.fit_transform(x['Employment Status'])
x['Type of Loan']=lb.fit_transform(x['Type of Loan'])

# %%
x.head(2)
# Out:
#    Age  Gender  Marital Status  Education Level  Employment Status  \
# 0   60       1               1                2                  0
# 1   25       1               1                1                  2
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22             2685                          2
# 1                      0.20             2371                          9
#
#    Interest Rate  Loan Term  Type of Loan
# 0           2.65         48             2
# 1           5.19         60             0

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,
                                               test_size=0.2,
                                               random_state=22)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# -0.03455465848369754

# %%
df=pd.read_csv('/content/cars - cars.csv')
df.head(2)
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0        Maruti 800 AC BSII  1992          50000     100000  Petrol
# 1  Maruti Gypsy E MG410W ST  1995          95000     100000  Petrol
#
#   seller_type transmission                 owner
# 0  Individual       Manual  Fourth & Above Owner
# 1  Individual       Manual          Second Owner

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df['name'].value_counts()
df=df.drop(columns=['name'])

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  1992          50000     100000  Petrol  Individual       Manual
# 1  1995          95000     100000  Petrol  Individual       Manual
#
#                   owner
# 0  Fourth & Above Owner
# 1          Second Owner

# %%
x=df.drop(columns='km_driven')
y=df['km_driven']

# %%
x['fuel']=lb.fit_transform(x['fuel'])
x['seller_type']=lb.fit_transform(x['seller_type'])
x['transmission']=lb.fit_transform(x['transmission'])
x['owner']=lb.fit_transform((x['owner']))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,
                                               test_size=0.2,
                                               random_state=22)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.302030774035391
