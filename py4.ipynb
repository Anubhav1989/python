# %%
import pandas as pd
df=pd.read_csv('/content/covid_toy - covid_toy.csv')
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever']=df['fever'].fillna(df['fever'].mean())
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].map({'Female':1,'Male':0})

# %%
df['cough']=df['cough'].map({'Mild':0,'Strong':1})

# %%
df['city']=df['city'].map({'Kolkata':0,'Banglore':1,'Delhi':2,'Mumbai':3})

# %%
df['has_covid']=df['has_covid'].map({'No':0,'Yes':1})

# %%
df.sample(3)
# Out:
#     age  gender       fever  cough  city  has_covid
# 25   23       0  100.844444      0   3.0          0
# 70   68       1  101.000000      1   2.0          0
# 10   75       1  100.844444      0   2.0          0

# %%
df.dtypes
# Out:
# age            int64
# gender         int64
# fever        float64
# cough          int64
# city         float64
# has_covid      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    int64
#  2   fever      100 non-null    float64
#  3   cough      100 non-null    int64
#  4   city       70 non-null     float64
#  5   has_covid  100 non-null    int64
# dtypes: float64(2), int64(4)
# memory usage: 4.8 KB

# %%
df.describe()#statically view of data
# Out:
#               age      gender       fever       cough       city  has_covid
# count  100.000000  100.000000  100.000000  100.000000  70.000000     100.00
# mean    44.220000    0.590000  100.844444    0.380000   1.314286       0.45
# std     24.878931    0.494311    1.948380    0.487832   1.268833       0.50
# min      5.000000    0.000000   98.000000    0.000000   0.000000       0.00
# 25%     20.000000    0.000000   99.000000    0.000000   0.000000       0.00
# 50%     45.000000    1.000000  100.922222    0.000000   2.000000       0.00
# 75%     66.500000    1.000000  102.000000    1.000000   2.000000       1.00
# max     84.000000    1.000000  104.000000    1.000000   3.000000       1.00

# %%
df['fever']=df['fever'].astype(int)
df.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       0    103      0   0.0          0
# 1   27       0    100      0   2.0          1
# 2   42       0    101      0   2.0          0
# 3   31       1     98      0   0.0          0
# 4   65       1    101      0   3.0          0

# %%
a = df[['gender','fever']][3:7]
